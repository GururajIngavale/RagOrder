# %%
import mplfinance as mpf
import pandas as pd

# %%
df = pd.read_csv(r"C:\algo_trade\Gold_History.csv")
mpf.plot(df, type='candle', volume=True, style='yahoo',
         title="BTC Historical Data")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 df = pd.read_csv(r"C:\algo_trade\Gold_History.csv")
# ----> 2 mpf.plot(df, type='candle', volume=True, style='yahoo',
#       3          title="BTC Historical Data")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mplfinance\plotting.py:417, in plot(data, **kwargs)
#     414 # translate alias types:
#     415 config['type'] = _get_valid_plot_types(config['type'])
# --> 417 dates,opens,highs,lows,closes,volumes = _check_and_prepare_data(data, config)
#     419 config['xlim'] = _check_and_convert_xlim_configuration(data, config)
#     421 if config['type'] in VALID_PMOVE_TYPES and config['addplot'] is not None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mplfinance\_arg_validators.py:32, in _check_and_prepare_data(data, config)
# ...
